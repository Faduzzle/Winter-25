# %%
import pandas as pd
import numpy as np
import yfinance as yf
import datetime
import bs4 as bs
import pickle
import requests as requests
import matplotlib.pyplot as plt

# %%
stocklist =['tsla']
optionsX = pd.DataFrame()

for x in stocklist:
    print(x)
    tk = yf.Ticker(x)  
    exps = pd.Series(tk.options)  #expiration dates
    try:
        for e in exps:
            print(e)
            opt = tk.option_chain(e)
            opt = pd.concat(opt.calls)
            opt = pd.concat(opt.puts)
            opt['expirationDate'] = e
            opt['Symbol'] = x
            optionsX = pd.concat(opt)
    except:
        pass
optionsX
# Out:
# tsla
# 2025-01-17
# Empty DataFrame
# Columns: []
# Index: []

# %%
tsla = yf.Ticker('tsla')
e = tsla.options    #expiry

# %% [markdown]
# This seems to work, for each expiration I have the option chain that expires at a specific date

# %%
calls = pd.DataFrame()
puts = pd.DataFrame()

option_chain1 = pd.DataFrame({'Calls': [],'Puts': []})
rows_to_add = []
for i in e:
    new_row = {'Calls':tsla.option_chain(i).calls,'Puts':tsla.option_chain(i).puts}
    new_row['expiration date'] = str(i)
    rows
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[187], line 8
#       6 for i in e:
#       7     new_row = [{'Calls':tsla.option_chain(i).calls,'Puts':tsla.option_chain(i).puts}]
# ----> 8     new_row['expiration date'] = str(i)
#
# TypeError: list indices must be integers or slices, not str

# %%
rows_to_add
# Out:
# []

# %%
option_chain1
# Out:
# Empty DataFrame
# Columns: [Calls, Puts]
# Index: []

# %%
rows_to_add
# Out:
# [{'Calls':           contractSymbol             lastTradeDate  strike  lastPrice     bid  \
#   0    TSLA270115C00005000 2025-01-13 17:22:15+00:00     5.0     390.25  396.00
#   1    TSLA270115C00010000 2025-01-13 17:24:38+00:00    10.0     387.08  391.25
#   2    TSLA270115C00015000 2025-01-13 15:45:07+00:00    15.0     378.45  387.00
#   3    TSLA270115C00020000 2025-01-13 15:07:40+00:00    20.0     375.00  382.00
#   4    TSLA270115C00025000 2025-01-13 18:16:42+00:00    25.0     374.60  378.00
#   ..                   ...                       ...     ...        ...     ...
#   116  TSLA270115C00920000 2025-01-07 19:34:15+00:00   920.0      51.70   52.20
#   117  TSLA270115C00930000 2025-01-13 19:42:03+00:00   930.0      49.16   51.65
#   118  TSLA270115C00940000 2025-01-13 17:05:36+00:00   940.0      46.85   50.85
#   119  TSLA270115C00950000 2025-01-13 18:39:27+00:00   950.0      50.18   50.05
#   120  TSLA270115C00960000 2025-01-13 20:59:58+00:00   960.0      49.15   49.30
#
# ...

# %% [markdown]
# Now trying to add it to option_chain1

# %%
option_chain1 = pd.concat()

# %% [markdown]
# Here is trash code

# %%
option_chain1.size
# Out:
# 0

# %%
option_chain1 = pd.DataFrame({'Calls':calls, 'Puts':puts})
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[123], line 1
# ----> 1 calls = tsla_options.calls
#       2 option_chain1 = pd.DataFrame({'Calls':calls, 'Puts':puts})
#
# AttributeError: 'tuple' object has no attribute 'calls'

# %%
opt
# Out:
# Options(calls=          contractSymbol             lastTradeDate  strike  lastPrice     bid  \
# 0    TSLA250117C00005000 2025-01-10 19:35:20+00:00     5.0     390.48  388.90
# 1    TSLA250117C00010000 2025-01-10 18:02:13+00:00    10.0     384.48  384.00
# 2    TSLA250117C00015000 2025-01-10 17:59:50+00:00    15.0     379.60  379.05
# 3    TSLA250117C00020000 2025-01-10 16:33:43+00:00    20.0     367.93  373.90
# 4    TSLA250117C00025000 2025-01-10 19:52:37+00:00    25.0     370.53  368.90
# ..                   ...                       ...     ...        ...     ...
# 210  TSLA250117C00920000 2025-01-02 15:24:37+00:00   920.0       0.02    0.00
# 211  TSLA250117C00930000 2025-01-07 15:43:20+00:00   930.0       0.01    0.00
# 212  TSLA250117C00940000 2025-01-03 20:46:09+00:00   940.0       0.01    0.00
# 213  TSLA250117C00950000 2025-01-07 15:29:50+00:00   950.0       0.01    0.00
# 214  TSLA250117C00960000 2025-01-10 17:36:04+00:00   960.0       0.01    0.00
#
# ...

# %%
optionsX.size
# Out:
# 0

# %%
tsla_options = yf.Ticker("tsla")
tsla_options.options    #expiration
# Out:
# ('2025-01-17',
#  '2025-01-24',
#  '2025-01-31',
#  '2025-02-07',
#  '2025-02-14',
#  '2025-02-21',
#  '2025-02-28',
#  '2025-03-21',
#  '2025-04-17',
#  '2025-05-16',
#  '2025-06-20',
#  '2025-07-18',
#  '2025-08-15',
#  '2025-09-19',
#  '2025-11-21',
#  '2025-12-19',
#  '2026-01-16',
#  '2026-06-18',
#  '2026-12-18',
#  '2027-01-15')

# %%
tsla_options.option_chain(e)
# Out:
# Options(calls=          contractSymbol             lastTradeDate  strike  lastPrice  bid  \
# 0    TSLA250117C00005000 2025-01-10 19:35:20+00:00     5.0     390.48  0.0
# 1    TSLA250117C00010000 2025-01-10 18:02:13+00:00    10.0     384.48  0.0
# 2    TSLA250117C00015000 2025-01-10 17:59:50+00:00    15.0     379.60  0.0
# 3    TSLA250117C00020000 2025-01-10 16:33:43+00:00    20.0     367.93  0.0
# 4    TSLA250117C00025000 2025-01-10 19:52:37+00:00    25.0     370.53  0.0
# ..                   ...                       ...     ...        ...  ...
# 210  TSLA250117C00920000 2025-01-02 15:24:37+00:00   920.0       0.02  0.0
# 211  TSLA250117C00930000 2025-01-07 15:43:20+00:00   930.0       0.01  0.0
# 212  TSLA250117C00940000 2025-01-03 20:46:09+00:00   940.0       0.01  0.0
# 213  TSLA250117C00950000 2025-01-07 15:29:50+00:00   950.0       0.01  0.0
# 214  TSLA250117C00960000 2025-01-10 17:36:04+00:00   960.0       0.01  0.0
#
# ...

# %%
tsla_options.option_chain(e).calls
# Out:
#           contractSymbol             lastTradeDate  strike  lastPrice  bid  \
# 0    TSLA250117C00005000 2025-01-10 19:35:20+00:00     5.0     390.48  0.0
# 1    TSLA250117C00010000 2025-01-10 18:02:13+00:00    10.0     384.48  0.0
# 2    TSLA250117C00015000 2025-01-10 17:59:50+00:00    15.0     379.60  0.0
# 3    TSLA250117C00020000 2025-01-10 16:33:43+00:00    20.0     367.93  0.0
# 4    TSLA250117C00025000 2025-01-10 19:52:37+00:00    25.0     370.53  0.0
# ..                   ...                       ...     ...        ...  ...
# 210  TSLA250117C00920000 2025-01-02 15:24:37+00:00   920.0       0.02  0.0
# 211  TSLA250117C00930000 2025-01-07 15:43:20+00:00   930.0       0.01  0.0
# 212  TSLA250117C00940000 2025-01-03 20:46:09+00:00   940.0       0.01  0.0
# 213  TSLA250117C00950000 2025-01-07 15:29:50+00:00   950.0       0.01  0.0
# 214  TSLA250117C00960000 2025-01-10 17:36:04+00:00   960.0       0.01  0.0
#
# ...

# %%
tsla_options.option_chain(e).puts
# Out:
#           contractSymbol             lastTradeDate  strike  lastPrice  bid  \
# 0    TSLA250117P00005000 2025-01-10 17:35:12+00:00     5.0       0.01  0.0
# 1    TSLA250117P00010000 2025-01-10 18:58:01+00:00    10.0       0.01  0.0
# 2    TSLA250117P00015000 2024-12-19 16:01:42+00:00    15.0       0.01  0.0
# 3    TSLA250117P00020000 2024-12-11 20:34:02+00:00    20.0       0.01  0.0
# 4    TSLA250117P00025000 2024-12-16 14:38:15+00:00    25.0       0.01  0.0
# ..                   ...                       ...     ...        ...  ...
# 186  TSLA250117P00840000 2024-12-26 14:52:50+00:00   840.0     386.65  0.0
# 187  TSLA250117P00850000 2025-01-07 20:40:22+00:00   850.0     457.20  0.0
# 188  TSLA250117P00940000 2025-01-10 15:18:41+00:00   940.0     552.23  0.0
# 189  TSLA250117P00950000 2024-12-30 16:54:26+00:00   950.0     526.67  0.0
# 190  TSLA250117P00960000 2024-12-31 20:33:33+00:00   960.0     552.00  0.0
#
# ...
