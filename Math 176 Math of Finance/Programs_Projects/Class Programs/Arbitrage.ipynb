# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
class sports_arbi:

    def __init__(self,A,B,n):
        self.x = (n*(1+B))/(2+A+B)
        self.p = (n*(A*B-1))/(2+A+B)
        self.k = np.linspace(self.x-(n-self.x)/2,1.02*n,400)
        k=np.linspace(self.x-(n-self.x)/2,1.02*n,400)
        self.bound_1 = (B*n)/(B+1)
        self.bound_2 = n/(A+1)
        self.y1 = -k + B*(n-k)
        self.y2 = A*k - (n-k)

# %%
parameters = pd.Series(dtype=float)
parameters['Oa'] = 5
parameters['Ob'] = 7/5

p = parameters

# %%
p1 = sports_arbi(p.Oa,p.Ob,240)
print(p1.x)
print(p1.p)
# Out:
# 68.57142857142857
# 171.42857142857142

# %%
if p1.bound_1 < p1.bound_2:
    print('To ensure profit the bounds are ' +str(p1.bound_1)+ '  <  x  <  '+str(p1.bound_2))

else:
    print('To ensure profit the bounds are ' +str(p1.bound_2)+ '  <  x  <  '+str(p1.bound_1))
# Out:
# To ensure profit the bounds are 40.0  <  x  <  140.0

# %%
plt.plot(p1.k,p1.y1,label = "First Event")
plt.plot(p1.k,p1.y2,label = "Second Event")
plt.axhline(y=p1.p, color='r', linestyle='--', label='Max Profit = '+str(p1.p))
plt.grid()
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5));
