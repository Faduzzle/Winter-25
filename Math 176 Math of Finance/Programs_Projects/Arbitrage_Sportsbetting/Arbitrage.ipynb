# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
class sports_arbi:

    def __init__(self,A,B,n):
        self.k = np.linspace(0,1.02*n,400)
        k=np.linspace(0,1.02*n,400)
        self.x = (n*(1+B))/(2+A+B)
        self.p = (n*(A*B-1))/(2+A+B)
        self.bound_1 = (B*n)/(B+1)
        self.bound_2 = n/(A+1)
        self.y1 = -k + B*(n-k)
        self.y2 = A*k - (n-k)

# %%
p1 = sports_arbi(2/3,2,100)
print(p1.x)
print(p1.p)
# Out:
# 64.28571428571429
# 7.142857142857142

# %%
if p1.bound_1 < p1.bound_2:
    print('To ensure profit the bounds are ' +p1.bound_1+ '  <  x  <  '+p1.bound_2)

else:
    print('To ensure profit the bounds are ' +str(p1.bound_2)+ '  <  x  <  '+str(p1.bound_1))
# Out:
# To ensure profit the bounds are 60.00000000000001  <  x  <  66.66666666666667

# %%
plt.plot(p1.k,p1.y1,label = "First Event")
plt.plot(p1.k,p1.y2,label = "Second Event")
plt.axhline(y=p1.p, color='r', linestyle='--', label='y = 5')
plt.grid()
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5));
